# %% [markdown]
# ## Cómo interactuar con este cuaderno de Jupyter
# Este cuaderno contiene código ejecutable combinado con instrucciones para guiarte a través de la actividad.
#
# ### Escenario: El acertijo del rectángulo
# Acabas de comenzar tu pasantía en Code Wizards Inc., una empresa líder en desarrollo de software.
# En tu primer día, te entregan un script de Python que calcula el área de un rectángulo.
# No está funcionando correctamente, sin embargo. Tu supervisor menciona que hay un pequeño error y te desafía a encontrarlo y corregirlo.
#
# ### Instrucciones:
# - Lee cuidadosamente el fragmento de código proporcionado y luego ejecútalo.
# - El código define la longitud y el ancho de un rectángulo, calcula el área y luego intenta imprimir el resultado.
# - Presta mucha atención a la salida - ¿es correcta el área calculada?
#
# ### Pistas
# - **Identifica y Corrige el Error:** Si la salida no es lo que esperabas, usa tu conocimiento de cómo calcular el área de un rectángulo (área = longitud * ancho) para detectar el error en el código. Modifica una línea de código para corregir el cálculo.
# - **Ejecuta el Programa de Nuevo:** Ejecuta el script modificado y verifica que ahora calcule e imprima correctamente el área del rectángulo. La salida debe indicar claramente el área calculada.

# %%
# The Code

length = 5
width = 3

# Calculate the area
area = length + width # Modify this line of code

# Print the result
print("The area of the rectangle is:", area)
# Out:
# The area of the rectangle is: 8
