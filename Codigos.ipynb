# %%
def outer_function():
    outer_var = "Hello from outer!"
    
    def inner_function():
        # Accede a outer_var
        # nonlocal outer_var
        outer_var = "Hello from inner!"

        print(outer_var.upper())
    
    inner_function()

    print(outer_var)

outer_function()
# Out:
# HELLO FROM INNER!
# Hello from outer!
