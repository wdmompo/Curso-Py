# %%
def outer_function():
    outer_var = "Hello from outer!"
    
    def inner_function():
        # Accede a outer_var
        # nonlocal outer_var
        outer_var = "Hello from inner!"

        print(outer_var.upper())
    
    inner_function()

    print(outer_var)

outer_function()
# Out:
# HELLO FROM INNER!
# Hello from outer!

# %%
def display_color_works():
  shirt_color = "Pink"
  print("First shirt color is:", shirt_color)
  
def display_color_failure():
  # Try to access 'color' directly (this will cause an error)
  print("Your shirt color is:", shirt_color)

# The shirt_color variable is in scope in this function
display_color_works()

# The shirt_color variable is not in scope in this function
display_color_failure()
# Out:
# First shirt color is: Pink
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 13
#      10 display_color_works()
#      12 # The shirt_color variable is not in scope in this function
# ---> 13 display_color_failure()
#
# Cell In[5], line 7, in display_color_failure()
#       5 def display_color_failure():
#       6   # Try to access 'color' directly (this will cause an error)
# ----> 7   print("Your shirt color is:", shirt_color)
#
# NameError: name 'shirt_color' is not defined
